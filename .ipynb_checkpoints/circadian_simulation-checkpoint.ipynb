# %%
import json
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp, odeint
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from matplotlib import font_manager
from matplotlib import cm
import seaborn as sns

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['font.weight'] = 'bold'

# %%
protein_mapping = {
    "x1": "Clock/Bmal_N",
    "x2": "Per/Cry_N^tot",
    "x5": "Rev-Erb_N",
    "x6": "Ror_N",
    "y1": "Per",
    "y2": "Cry",
    "y3": "Rev-Erb",
    "y4": "Ror",
    "y5": "Bmal",
    "y6": "Clock",
    "z1": "Cry_C",
    "z2": "Per_C^tot",
    "z4": "Per/Cry_C^tot",
    "z5": "Clock_C",
    "z6": "Rev-Erb_C",
    "z7": "Ror_C",
    "z8": "Bmal_C",
    "z9": "Clock/Bmal_C"
}
params_list = [
    # degradation rates
    'dr_x1', 'dr_x2', 'dr_x5', 'dr_x6',
    'dr_y1', 'dr_y2', 'dr_y3', 'dr_y4', 'dr_y5', 'dr_y6',
    'dr_z1', 'dr_z2', 'dr_z5', 'dr_z6', 'dr_z7', 'dr_z8',
    # reaction rates for complex formation/dissociation
    'kf_z9', 'kf_z4', 'kd_z9', 'kd_z4',
    # transcription rates
    'tr_y1', 'tr_y2', 'tr_y3', 'tr_y4', 'tr_y5', 'tr_y6',
    # activation/inhibition rates
    'ar_y1', 'ar_y2', 'ar_y3', 'ar_y4', 'ar_y5', 'ar_y6',
    'ir_y1', 'ir_y2', 'ir_y21', 'ir_y3', 'ir_y4', 'ir_y5', 'ir_y6',
    # transcription fold activation
    'a', 'd', 'g', 'h', 'i', 'j',
    # production rates
    'pr_z1', 'pr_z2', 'pr_z5', 'pr_z6', 'pr_z7', 'pr_z8',
    # import/export rates
    'impr_z4', 'impr_z6', 'impr_z7', 'impr_z9',
    'expr_x1', 'expr_x2',
    # hill coefficients
    'b', 'c', 'e', 'f', 'f1',
    # volume proportions
    'vc', 'vn'
]

# %%
def initialize_params(literature = False):
    '''
    Args >>>
    - literature: boolean
    
    To use the parameters from the literature, set the boolean to True.
    These parameters from the literature are to test and validate our results.
    '''
    if literature:
        return pd.concat([
            pd.read_json('degradation_rates.json', typ = 'series'),
            pd.read_json('reaction_rates.json', typ = 'series'),
            pd.read_json('transcription_rates.json', typ = 'series'),
            pd.read_json('activation_inhibition_rates.json', typ = 'series'),
            pd.read_json('transcription_fold_activation_rates.json', typ = 'series'),
            pd.read_json('production_rates.json', typ = 'series'),
            pd.read_json('import_export_rates.json', typ = 'series'),
            pd.read_json('hill_coefficients_of_transcription.json', typ = 'series'),
            pd.read_json('volume_proportions.json', typ = 'series')
        ])
    else:
        tmp = np.random.rand()
        values = np.concatenate((
            np.random.rand(16), # degradation rates
            np.random.rand(2), # reaction rates for complex formation
            np.random.rand(2), # reaction rates for complex dissociation
            np.random.rand(6), # transcription rates
            np.random.rand(13), # activation/inhibition rates
            np.random.rand(6) * 10, # transcription fold activation
            np.random.rand(6) * 1e3, # production rates
            np.random.rand(6), # import/export rates
            np.random.rand(5), # hill coefficients
            np.array([tmp, 1-tmp]) # volume proportions
        ))
        return pd.Series(values, params_list)

# %%
def circadian_clock(t, proteins, params):
    '''
    function to compute the odes in the circadian clock model
    - these odes are based on the model proposed by Relogio et al. (2011) [1]
      and later modified by Hesse et al. (2021) [2]
    this is just the core clock which does not capture any interactions with external factors like drugs or stimuli (like light)
    TODO: these external factors would be incorporated in a separate function which computes the coupled odes for the factors
    TODO: update the function to take separate input for genes and proteins

    References:
    [1] A. Rel´ogio, P. O. Westermark, T. Wallach, K. Schellenberg, A. Kramer, and H. Herzel, Tuning the mammalian circadian clock: robust synergy of two loops, PLoS computational biology, 7 (2011), p. e1002309.
    [2] J. Hesse, J. Martinelli, O. Aboumanify, A. Ballesta, and A. Rel´ogio, A mathematical model of the circadian clock and drug pharmacology to optimize irinotecan administration timing in colorectal cancer, Computational and Structural Biotechnology Journal, 19 (2021), pp. 5170–5183.
    '''
    # unpacking the values of the proteins
    x1, x2, x5, x6 = proteins[:4]
    y1, y2, y3, y4, y5 = proteins[4:9]
    z1, z2, z4, z5, z6, z7, z8, z9 = proteins[9:17]
    y6 = proteins[17]
    ratio = params['vc'] / params['vn']

    # odes for nuclear proteins and protein complexes
    dx1dt = params['impr_z9'] * z9 - params['expr_x1'] * x1 - params['dr_x1'] * x1
    dx2dt = params['impr_z4'] * z4 - params['expr_x2'] * x2 - params['dr_x2'] * x2
    dx5dt = params['impr_z6'] * z6 - params['dr_x5'] * x5
    dx6dt = params['impr_z7'] * z7 - params['dr_x6'] * x6

    # odes for core genes for the circadian clock
    dy1dthelper = (x1 / params['ar_y1'] / 1e-9)**params['b']
    dy1dt = params['tr_y1'] * 1e-9 * (1 + params['a'] * dy1dthelper) / (1 + dy1dthelper * (1 + (x2 / params['ir_y1'] / 1e-9)**params['c'])) - params['dr_y1'] * y1
    dy2dthelper = (x1 / params['ar_y2'] / 1e-9)**params['e']
    dy2dt = params['tr_y2'] * 1e-9 * (1 + params['d'] * dy2dthelper) / (1 + dy2dthelper * (1 + (x2 / params['ir_y2'] / 1e-9)**params['f'])) * (1 / (1 + (x5 / params['ir_y21'] / 1e-9)**params['f1'])) - params['dr_y2'] * y2
    dy3dthelper = (x1 / params['ar_y3'] / 1e-9)**params['b']
    dy3dt = params['tr_y3'] * 1e-9 * (1 + params['g'] * dy3dthelper) / (1 + dy3dthelper * (1 + (x2 / params['ir_y3'] / 1e-9)**params['c'])) - params['dr_y3'] * y3
    dy4dthelper = (x1 / params['ar_y4'] / 1e-9)**params['b']
    dy4dt = params['tr_y4'] * 1e-9 * (1 + params['h'] * dy4dthelper) / (1 + dy4dthelper * (1 + (x2 / params['ir_y4'] / 1e-9)**params['c'])) - params['dr_y4'] * y4
    dy5dthelper = (x6 / params['ar_y5'] / 1e-9)**params['b']
    dy5dt = params['tr_y5'] * 1e-9 * (1 + params['i'] * dy5dthelper) / (1 + dy5dthelper + (x5 / params['ir_y5'] / 1e-9)**params['c']) - params['dr_y5'] * y5
    dy6dthelper = (x6 / params['ar_y6'] / 1e-9)**params['b']
    dy6dt = params['tr_y6'] * 1e-9 * (1 + params['j'] * dy6dthelper) / (1 + dy6dthelper + (x5 / params['ir_y6'] / 1e-9)**params['c']) - params['dr_y6'] * y6

    # odes for cytoplasmic proteins and protein complexes
    dz1dt = params['pr_z1'] * y2 + params['kd_z4'] * z4 - params['kf_z4'] * 1e9 * z1 * z2 - params['dr_z1'] * z1
    dz2dt = params['pr_z2'] * y1 + params['kd_z4'] * z4 - params['kf_z4'] * 1e9 * z1 * z2 - params['dr_z2'] * z2
    dz4dt = params['kf_z4'] * 1e9 * z1 * z2 + ratio * params['expr_x2'] * x2 - ratio * params['impr_z4'] * z4 - params['kd_z4'] * z4
    dz5dt = params['pr_z5'] * y6 + params['kd_z9'] * z9 - params['kf_z9'] * 1e9 * z8 * z5 - params['dr_z5'] * z5
    dz6dt = params['pr_z6'] * y3 - ratio * params['impr_z6'] * z6 - params['dr_z6'] * z6
    dz7dt = params['pr_z7'] * y4 - ratio * params['impr_z7'] * z7 - params['dr_z7'] * z7
    dz8dt = params['pr_z8'] * y5 + params['kd_z9'] * z9 - params['kf_z9'] * 1e9 * z5 * z8 - params['dr_z8'] * z8
    dz9dt = params['kf_z9'] * 1e9 * z8 * z5 + ratio * params['expr_x1'] * x1 - ratio * params['impr_z9'] * z9 - params['kd_z9'] * z9
    
    odes = [dx1dt, dx2dt, dx5dt, dx6dt, dy1dt, dy2dt, dy3dt, dy4dt, dy5dt, dz1dt, dz2dt, dz4dt, dz5dt, dz6dt, dz7dt, dz8dt, dz9dt, dy6dt]
    return odes

# %%
class CircadianModel:
    '''
    CircadianModel is a class to aid the creation of the model, simplify solving the odes and act as a utility for model training and parameter optimization.
    '''
    def __init__(self, init, t_start, t_end, dt, params):
        # initial value of the variables -> genes and proteins
        self.init = init
        # time based variables -> start time of the simulation, end time and time step
        self.t_start = t_start
        self.t_end = t_end
        self.dt = dt
        self.t_eval = np.linspace(t_start, t_end, int((t_end - t_start)/dt) + 1)
        # parameters for the system of odes
        self.params = params
        # to track the past values of the parameters -> used to optimize the values
        self.prev_params = params
        # to track the past values of the loss/objective function
        self.prev_loss = np.inf
        
    def solver(self, params = None, method = 'Radau', atol = 1e-9, rtol = 1e-9):
        '''
        Args >>>
        - params: values for the parameters
        - method, atol, rtol: for the solver
        
        TODO: init values could also be an input
        '''
        if params is not None:
            parameters = params
        else:
            parameters = self.params
        return solve_ivp(
            fun = lambda t, p: circadian_clock(t, p, parameters.to_dict()),
            t_span = [self.t_start, self.t_end],
            y0 = list(self.init.values()),
            t_eval = self.t_eval,
            method = method,
            atol = atol,
            rtol = rtol
        )
    
    def processing_solution(self, solution, params = None, interval = 48, jumps = 4):
        '''
        Args >>>
        - solution: from the solver
        - params: value of parameters for the odes
        - interval: duration of the ode to process
        - jumps: resolution of the duration
        
        We have experimental data on protein properties which are a linear combination of the protein variables in the odes.
        To compare the solution of the odes with experimental data, we need to process the solution to arrive at the desired format
        
        FAR-FETCHED TODO: further simply the model to only use these experimental entities >> to be done based on time availability
        '''
        if params is not None:
            parameters = params
        else:
            parameters = self.params
        slice_start = int((self.t_end - interval) / self.dt)
        slice_end = int(self.t_end / self.dt)
        slice_step = int(jumps / self.dt)
        out = solution.y[:, slice_start:slice_end:slice_step]
        gene = out[[4, 5, 6, 7, 8, -1]]
        protein = np.zeros(gene.shape)
        # vc and vn are fractions to denote the volume of cytoplasm and nucleus respectively, and they "should" add to 1
        total = parameters['vc'] + parameters['vn']
        # the total concentration of the proteins are easier to measure compared to their cytoplasmic and nucleic concentrations
        # these total concentrations are expressed in terms of the cytoplasmic and nucleic species of these proteins and their complexes
        protein[0] = parameters['vc'] * (out[15] + out[16]) + parameters['vn'] * out[0]
        protein[1] = parameters['vc'] * (out[12] + out[16]) + parameters['vn'] * out[0]
        protein[2] = parameters['vc'] * (out[10] + out[11]) + parameters['vn'] * out[1]
        protein[3] = parameters['vc'] * (out[9] + out[11]) + parameters['vn'] * out[1]
        protein[4] = parameters['vc'] * out[13] + parameters['vn'] * out[2]
        protein[5] = parameters['vc'] * out[14] + parameters['vn'] * out[3]
        return gene, protein/total
    
    def objective_function(self, params, gene_targets, protein_targets, method = 'Radau', atol = 1e-9, rtol = 1e-9):
        '''
        Args >>>
        - gene_targets, protein_targets: data from experiments
        
        We define the objective function to optimize the parameters for the odes
        The objective function has the form of least squares, but the gene variables have been scaled to have similar importance in the objective function
        The gene variables are in picomol/L and protein variables are in nanomol/L
        
        TODO: while optimizing, the solver gets stuck in a pit so we are exploring ways to resolve this behavior and arrive at better parameters
        Currently, we are taking the largest moved parameter and shaking up the value to reach a different pit but this needs further work
        '''
        # solver attempts to solve the equation
        # if the solver fails to converge at a solution then we pick the largest changed parameter and update the value to hope for a different solution
        # the update is by a factor upto 1
        # NOTE. the print statements are a bit weird, and kept the way due to ongoing debugging? ignore them for now if it makes no sense.
        try:
            solution = self.solver(pd.Series(params, params_list), method, atol, rtol)
        except:
            update_index = int(np.argmax(np.abs(params - self.prev_params)))
            print('\twhat happened here?', update_index)
            new_params = initialize_params().to_numpy()
            print('\tOriginal: {}, Pot. Opt.: {}, Reinit.: {}'.format(self.prev_params.to_numpy()[update_index], params[update_index], new_params[update_index], self.prev_params.to_numpy()[update_index] * new_params[update_index]))
#             self.prev_params = pd.Series(np.copy(params), params_list)
            params[update_index] = self.prev_params.to_numpy()[update_index] * new_params[update_index]
            self.params = pd.Series(params, params_list)
            print('\tLoss achieved: ', self.prev_loss, np.abs(self.prev_params - self.params).max())
            self.prev_loss = np.inf
            raise ValueError('updated params...')
        gene_preds, protein_preds = self.processing_solution(solution)
        protein_preds = protein_preds[:, :6]
        # trying this thing? >>> experiment of many others
        # this experiment is to address any issue with the result from the solver
        # at times, the solver does not provide the entire solution due to instability from randomised parameters
        # this following line fills in the empty cells with repetition from the previously filled cells as a way to tackle this problem
        gene_preds = np.resize(gene_preds, gene_targets.shape); protein_preds = np.resize(protein_preds, protein_targets.shape)
        norm_gene = np.max(gene_targets, axis = 1).reshape(-1, 1)
        norm_protein = np.max(protein_targets, axis = 1).reshape(-1, 1)
        diff_gene = gene_targets - gene_preds
        diff_protein = protein_targets - protein_preds
        self.prev_loss = np.sqrt(np.mean((diff_gene)**2) * 1e6 + np.mean((diff_protein)**2))
        self.prev_params = pd.Series(np.copy(params), params_list)
        return np.sqrt(np.mean((diff_gene)**2) * 1e6 + np.mean((diff_protein)**2))

# %%
# vc + vn = 1; cytoplasmic and nucleic volumes sum to 1, they form the living cell
def volume_constraint(params):
    return params[-2] + params[-1] - 1

# now redundant, TO BE DELETED
def positive_constraint(params):
    return params

# %%
# testing the workflow and functions with parameters from the literature
with open('initial_values.json') as f:
    init = json.load(f)
t_start = 0
t_end = 600
dt = 0.1
# t_eval = np.linspace(t_start, t_end, int((t_end - t_start)/dt) + 1)
parameters = initialize_params(True)
clock = CircadianModel(init, t_start, t_end, dt, parameters)

# %%
soln = clock.solver()
# Out:
# <ipython-input-178-00ff8aa49707>:37: RuntimeWarning: invalid value encountered in double_scalars
#   dy5dthelper = (x6 / params['ar_y5'] / 1e-9)**params['b']
# <ipython-input-178-00ff8aa49707>:39: RuntimeWarning: invalid value encountered in double_scalars
#   dy6dthelper = (x6 / params['ar_y6'] / 1e-9)**params['b']
# <ipython-input-178-00ff8aa49707>:32: RuntimeWarning: invalid value encountered in double_scalars
#   dy2dt = params['tr_y2'] * 1e-9 * (1 + params['d'] * dy2dthelper) / (1 + dy2dthelper * (1 + (x2 / params['ir_y2'] / 1e-9)**params['f'])) * (1 / (1 + (x5 / params['ir_y21'] / 1e-9)**params['f1'])) - params['dr_y2'] * y2
# <ipython-input-178-00ff8aa49707>:38: RuntimeWarning: invalid value encountered in double_scalars
#   dy5dt = params['tr_y5'] * 1e-9 * (1 + params['i'] * dy5dthelper) / (1 + dy5dthelper + (x5 / params['ir_y5'] / 1e-9)**params['c']) - params['dr_y5'] * y5
# <ipython-input-178-00ff8aa49707>:40: RuntimeWarning: invalid value encountered in double_scalars
#   dy6dt = params['tr_y6'] * 1e-9 * (1 + params['j'] * dy6dthelper) / (1 + dy6dthelper + (x5 / params['ir_y6'] / 1e-9)**params['c']) - params['dr_y6'] * y6

# %%
plt_start = int((t_end - 48) / dt)
plt_end = int(t_end / dt)
fig, axes = plt.subplots(6, 3, figsize = (20,20), constrained_layout = True)
for i, ax in zip(range(len(init)), axes.flat):
    time = soln.t[plt_start:plt_end]
    prot = soln.y[i, plt_start:plt_end]
    ax.plot(time, prot, label = list(init.keys())[i], lw = 2)
    ax.tick_params(axis='both', which = 'major', labelsize = '15', width = 1.5)
    ax.yaxis.offsetText.set_fontsize(15)
    var = list(init.keys())[i]
    ax.set_title('{} ({})'.format(protein_mapping[var], var), fontsize = 18, weight = 'bold')
# _ = fig.supylabel('Concentration (nmol/L)', fontsize = 22, weight = 'bold')
# _ = fig.supxlabel('Time (hours)', fontsize = 22, weight = 'bold')
# plt.savefig('circadian_clock_portion.png', bbox_inches = 'tight', pad_inches = 0.4, dpi = 300)

# %%
plt_start = int(t_start / dt)
plt_end = int(t_end / dt)
fig, axes = plt.subplots(6, 3, figsize = (20,20), constrained_layout = True)
for i, ax in zip(range(len(init)), axes.flat):
    time = soln.t[plt_start:plt_end]
    prot = soln.y[i, plt_start:plt_end]
    ax.plot(time, prot, label = list(init.keys())[i], lw = 2)
    ax.tick_params(axis='both', which = 'major', labelsize = '15', width = 1.5)
    ax.yaxis.offsetText.set_fontsize(15)
    var = list(init.keys())[i]
    ax.set_title('{} ({})'.format(protein_mapping[var], var), fontsize = 18, weight = 'bold')
# _ = fig.supylabel('Concentration (nmol/L)', fontsize = 22, weight = 'bold')
# _ = fig.supxlabel('Time (hours)', fontsize = 22, weight = 'bold')
# plt.savefig('circadian_clock_entire_period.png', bbox_inches = 'tight', pad_inches = 0.4, dpi = 300)

# %%
# loading the processed data for gene and protein
# TODO: add the data processing routine
gene_data = pd.read_csv('processed_gene.csv')
protein_data = pd.read_csv('processed_protein.csv')

# %%
gene_data['id'] = ['y5', 'y6', 'y2', 'y1', 'y3', 'y4']
gene_targets = gene_data.sort_values('id').filter(regex='ct').to_numpy()

# %%
protein_targets = protein_data.filter(regex='ct').to_numpy()

# %%
# attempt at optimizing the parameters, we are training multiple models and eventually taking an ensemble average?
# either way, we can check multiple models and still pick the best one if not ensemble average
list_opt = []
for i in range(10):
    clock1 = CircadianModel(init, t_start, t_end, dt, initialize_params(False))
    print('-----> MODEL ', i)
    opt_params = None
    count = 0
    while count < 25 and opt_params is None:
        try:
            print('Attempt {} at minimization...'.format(count))
            opt_params = minimize(clock1.objective_function, clock1.params,
                                  args = (gene_targets, protein_targets),
                                  options = {'ftol': 1e-18, 'maxiter': 200},
                                  constraints = [{'type': 'eq', 'fun': volume_constraint}],
                                  bounds = [(0, None) for i in range(clock.params.shape[0] - 2)] + [(0, 1), (0, 1)]
                                 )
        except Exception as e:
            count += 1
            print(e)
            pass
    list_opt.append(opt_params)
# Out:
# -----> MODEL  0
# Attempt 0 at minimization...
# <ipython-input-178-00ff8aa49707>:30: RuntimeWarning: invalid value encountered in double_scalars
#   dy1dt = params['tr_y1'] * 1e-9 * (1 + params['a'] * dy1dthelper) / (1 + dy1dthelper * (1 + (x2 / params['ir_y1'] / 1e-9)**params['c'])) - params['dr_y1'] * y1
# <ipython-input-178-00ff8aa49707>:32: RuntimeWarning: invalid value encountered in double_scalars
#   dy2dt = params['tr_y2'] * 1e-9 * (1 + params['d'] * dy2dthelper) / (1 + dy2dthelper * (1 + (x2 / params['ir_y2'] / 1e-9)**params['f'])) * (1 / (1 + (x5 / params['ir_y21'] / 1e-9)**params['f1'])) - params['dr_y2'] * y2
# <ipython-input-178-00ff8aa49707>:34: RuntimeWarning: invalid value encountered in double_scalars
#   dy3dt = params['tr_y3'] * 1e-9 * (1 + params['g'] * dy3dthelper) / (1 + dy3dthelper * (1 + (x2 / params['ir_y3'] / 1e-9)**params['c'])) - params['dr_y3'] * y3
# <ipython-input-178-00ff8aa49707>:36: RuntimeWarning: invalid value encountered in double_scalars
#   dy4dt = params['tr_y4'] * 1e-9 * (1 + params['h'] * dy4dthelper) / (1 + dy4dthelper * (1 + (x2 / params['ir_y4'] / 1e-9)**params['c'])) - params['dr_y4'] * y4
# <ipython-input-178-00ff8aa49707>:37: RuntimeWarning: invalid value encountered in double_scalars
#   dy5dthelper = (x6 / params['ar_y5'] / 1e-9)**params['b']
# <ipython-input-178-00ff8aa49707>:39: RuntimeWarning: invalid value encountered in double_scalars
#   dy6dthelper = (x6 / params['ar_y6'] / 1e-9)**params['b']
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.7232060971418437, Reinit.: 0.7528580715369948
# 	Loss achieved:  1.0899412108139668e-06 0.15691087312072333
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.4779909992429188, Reinit.: 0.49456164531264424
# 	Loss achieved:  inf 0.32090375775540086
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.3139981146082413, Reinit.: 0.49872225393232994
# 	Loss achieved:  inf 0.31826217955259006
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.3166396928110521, Reinit.: 0.3780047866927254
# 	Loss achieved:  inf 0.3949059255300116
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.23999594683363054, Reinit.: 0.0009628393425532566
# 	Loss achieved:  inf 0.6342905638622697
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.0006113085013724409, Reinit.: 0.8240654640055897
# 	Loss achieved:  inf 0.11170116631627969
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.5232007060473625, Reinit.: 0.2321746758402643
# 	Loss achieved:  inf 0.48749373595723666
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.1474081364064055, Reinit.: 0.6404833218725797
# 	Loss achieved:  inf 0.228257812089056
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 34
# 	Original: 0.6349018723636422, Pot. Opt.: 0.40664406027458616, Reinit.: 0.9489699927542505
# 	Loss achieved:  inf 0.08634473084864147
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 12
# 	Original: 0.6795837543730576, Pot. Opt.: 0.7659284852216991, Reinit.: 0.18750459775019845
# 	Loss achieved:  inf 0.5521586758717678
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 12
# 	Original: 0.6795837543730576, Pot. Opt.: 0.12742507850128984, Reinit.: 0.5530016937107506
# 	Loss achieved:  inf 0.30377278718644607
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 12
# 	Original: 0.6795837543730576, Pot. Opt.: 0.37581096718661156, Reinit.: 0.6269742354343155
# 	Loss achieved:  inf 0.25350224956142814
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 12
# 	Original: 0.6795837543730576, Pot. Opt.: 0.4260815048116295, Reinit.: 0.3001554113928503
# 	Loss achieved:  inf 0.47560301300331476
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 12
# 	Original: 0.6795837543730576, Pot. Opt.: 0.20398074136974284, Reinit.: 0.9843581912158048
# 	Loss achieved:  inf 0.049842173602654444
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.1464092834231947, Reinit.: 0.052853635481799555
# 	Loss achieved:  inf 0.18587885405343285
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.010372602972416281, Reinit.: 0.32320751636506406
# 	Loss achieved:  inf 0.13282151101749934
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.06342994600834981, Reinit.: 0.2936279704709116
# 	Loss achieved:  inf 0.13862653999738972
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.05762491702845941, Reinit.: 0.5899177177181577
# 	Loss achieved:  inf 0.08047924539829711
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.11577221162755204, Reinit.: 0.7129330372949735
# 	Loss achieved:  inf 0.056337309694846543
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 20
# 	Original: 0.19625145702584915, Pot. Opt.: 0.1399141473310026, Reinit.: 0.9858968741503663
# 	Loss achieved:  inf 0.034430186568223387
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 25
# 	Original: 0.6210849297569027, Pot. Opt.: 0.5866547431886793, Reinit.: 0.5813504475032845
# 	Loss achieved:  inf 0.2600169279051813
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 25
# 	Original: 0.6210849297569027, Pot. Opt.: 0.36106800185172133, Reinit.: 0.5380991755111483
# 	Loss achieved:  inf 0.2868796411323139
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 25
# 	Original: 0.6210849297569027, Pot. Opt.: 0.33420528862458876, Reinit.: 0.7223267586101175
# 	Loss achieved:  inf 0.17245866562400664
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 25
# 	Original: 0.6210849297569027, Pot. Opt.: 0.448626264132896, Reinit.: 0.02218811542813659
# 	Loss achieved:  inf 0.6073042256447804
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 25
# 	Original: 0.6210849297569027, Pot. Opt.: 0.013780704112122262, Reinit.: 0.5428197986136322
# 	Loss achieved:  inf 0.2839477332642989
# updated params...
# -----> MODEL  1
# Attempt 0 at minimization...
# <ipython-input-178-00ff8aa49707>:38: RuntimeWarning: invalid value encountered in double_scalars
#   dy5dt = params['tr_y5'] * 1e-9 * (1 + params['i'] * dy5dthelper) / (1 + dy5dthelper + (x5 / params['ir_y5'] / 1e-9)**params['c']) - params['dr_y5'] * y5
# <ipython-input-178-00ff8aa49707>:40: RuntimeWarning: invalid value encountered in double_scalars
#   dy6dt = params['tr_y6'] * 1e-9 * (1 + params['j'] * dy6dthelper) / (1 + dy6dthelper + (x5 / params['ir_y6'] / 1e-9)**params['c']) - params['dr_y6'] * y6
# <ipython-input-178-00ff8aa49707>:29: RuntimeWarning: invalid value encountered in double_scalars
#   dy1dthelper = (x1 / params['ar_y1'] / 1e-9)**params['b']
# <ipython-input-178-00ff8aa49707>:31: RuntimeWarning: invalid value encountered in double_scalars
#   dy2dthelper = (x1 / params['ar_y2'] / 1e-9)**params['e']
# <ipython-input-178-00ff8aa49707>:33: RuntimeWarning: invalid value encountered in double_scalars
#   dy3dthelper = (x1 / params['ar_y3'] / 1e-9)**params['b']
# <ipython-input-178-00ff8aa49707>:35: RuntimeWarning: invalid value encountered in double_scalars
#   dy4dthelper = (x1 / params['ar_y4'] / 1e-9)**params['b']
# 	what happened here? 63
# 	Original: 0.11139710532166265, Pot. Opt.: 6.938893903907228e-17, Reinit.: 0.7691736899797004
# 	Loss achieved:  1.7136497918414092e-06 0.11139709042050139
# updated params...
# Attempt 1 at minimization...
# <ipython-input-178-00ff8aa49707>:36: RuntimeWarning: divide by zero encountered in double_scalars
#   dy4dt = params['tr_y4'] * 1e-9 * (1 + params['h'] * dy4dthelper) / (1 + dy4dthelper * (1 + (x2 / params['ir_y4'] / 1e-9)**params['c'])) - params['dr_y4'] * y4
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.16630572134910018, Reinit.: 0.15489854527722535
# 	Loss achieved:  1.7971331552003957e-06 0.10074846721702851
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.01846617459195741, Reinit.: 0.7734238952859422
# 	Loss achieved:  inf 0.03334516533048559
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 25
# 	Original: 0.3909799204907369, Pot. Opt.: 0.3576347551602513, Reinit.: 0.2702097200382926
# 	Loss achieved:  inf 0.285333345634341
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 25
# 	Original: 0.3909799204907369, Pot. Opt.: 0.1056465748563959, Reinit.: 0.4726102472189221
# 	Loss achieved:  inf 0.20619880360997522
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 25
# 	Original: 0.3909799204907369, Pot. Opt.: 0.18478111688076165, Reinit.: 0.7655547639182971
# 	Loss achieved:  inf 0.0916633797626562
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 25
# 	Original: 0.3909799204907369, Pot. Opt.: 0.29931654072808067, Reinit.: 0.9629574773299684
# 	Loss achieved:  inf 0.02717474883581661
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.9455219559873103, Reinit.: 0.28830859923445196
# 	Loss achieved:  inf 0.6922598803756039
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.2804368244475229, Reinit.: 0.33643713930896757
# 	Loss achieved:  inf 0.6454454080371748
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.32725129678595205, Reinit.: 0.05988045819254373
# 	Loss achieved:  inf 0.9144511804559405
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.058245524367186295, Reinit.: 0.44964306073300975
# 	Loss achieved:  inf 0.5353303813015432
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.43736632352158367, Reinit.: 0.27168403366716676
# 	Loss achieved:  inf 0.7084305405220184
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.26426616430110855, Reinit.: 0.68279135990124
# 	Loss achieved:  inf 0.3085477989654891
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.6641489058576378, Reinit.: 0.17655723781345145
# 	Loss achieved:  inf 0.8009600613893095
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 62
# 	Original: 0.9726967048231269, Pot. Opt.: 0.1717366434338174, Reinit.: 0.983112267222182
# 	Loss achieved:  inf 0.02717473393465538
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 63
# 	Original: 0.027303310078034333, Pot. Opt.: 0.054478044012689714, Reinit.: 0.26030507929919966
# 	Loss achieved:  inf 0.02701118916596168
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.09220345264302424, Reinit.: 0.4709367486831596
# 	Loss achieved:  inf 0.06307208600003462
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.05614255580895129, Reinit.: 0.3570173221521169
# 	Loss achieved:  inf 0.07665294962901797
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.04256169217996795, Reinit.: 0.3957445940387484
# 	Loss achieved:  inf 0.07203609178281398
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.04717855002617193, Reinit.: 0.4270779518122304
# 	Loss achieved:  inf 0.06830069675917552
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.050913945049810394, Reinit.: 0.3622461495072823
# 	Loss achieved:  inf 0.0760295968487909
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 5
# 	Original: 0.11921464180898592, Pot. Opt.: 0.04318504496019502, Reinit.: 0.8769785989448519
# 	Loss achieved:  inf 0.025961735814207937
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 58
# 	Original: 0.23131098377000162, Pot. Opt.: 0.25727271958420955, Reinit.: 0.8699976619340971
# 	Loss achieved:  inf 0.030070968710424334
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 58
# 	Original: 0.23131098377000162, Pot. Opt.: 0.20124001505957728, Reinit.: 0.7473896208919069
# 	Loss achieved:  inf 0.05843155530200608
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 58
# 	Original: 0.23131098377000162, Pot. Opt.: 0.17287942846799553, Reinit.: 0.4022530216067004
# 	Loss achieved:  inf 0.13826544161770005
# updated params...
# -----> MODEL  2
# Attempt 0 at minimization...
# 	what happened here? 5
# 	Original: 0.03082662323173007, Pot. Opt.: 0.048619824799392, Reinit.: 0.6010511701475809
# 	Loss achieved:  4.309758172083876e-06 0.01229824526660011
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 5
# 	Original: 0.03082662323173007, Pot. Opt.: 0.01852837796512996, Reinit.: 0.5714286099469339
# 	Loss achieved:  inf 0.013211408769064698
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 5
# 	Original: 0.03082662323173007, Pot. Opt.: 0.017615214462665372, Reinit.: 0.20355365739152909
# 	Loss achieved:  inf 0.024551751327880737
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 5
# 	Original: 0.03082662323173007, Pot. Opt.: 0.0062748719038493335, Reinit.: 0.9762720675238896
# 	Loss achieved:  inf 0.011697321745614551
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 63
# 	Original: 0.011697321745614556, Pot. Opt.: 5.204170427930421e-18, Reinit.: 0.11540834643375164
# 	Loss achieved:  inf 0.011697306844453359
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 63
# 	Original: 0.000403968269679556, Pot. Opt.: 7.822518674482914e-17, Reinit.: 0.7536627981099676
# 	Loss achieved:  2.012072665336492e-06 0.0004039533685182839
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 63
# 	Original: 0.00030447075763553004, Pot. Opt.: 0.0, Reinit.: 0.1944760958952445
# 	Loss achieved:  1.9572340734967233e-06 0.00024525847337630494
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.08900177531737263, Reinit.: 0.31717027954212373
# 	Loss achieved:  1.5329687065610528e-06 0.045578985565864594
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.02117116341022462, Reinit.: 0.8329441255587294
# 	Loss achieved:  inf 0.011151004506285665
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.05559914446980355, Reinit.: 0.9000318759743763
# 	Loss achieved:  inf 0.006672887171570545
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.060077261804518674, Reinit.: 0.15725233375303105
# 	Loss achieved:  inf 0.056253532271236695
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.010496616704852526, Reinit.: 0.37675728449715573
# 	Loss achieved:  inf 0.041601544108077246
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.025148604868011973, Reinit.: 0.06095205163408779
# 	Loss achieved:  inf 0.06268159044911557
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.004068558526973643, Reinit.: 0.19495586905340623
# 	Loss achieved:  inf 0.05373681567301141
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 5
# 	Original: 0.06675014897608922, Pot. Opt.: 0.013013333303077808, Reinit.: 0.9592922539539613
# 	Loss achieved:  inf 0.005275793107031829
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.18297293430552614, Reinit.: 0.4960796124782413
# 	Loss achieved:  inf 0.08954521225425392
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.08815192894424038, Reinit.: 0.9472570765710123
# 	Loss achieved:  inf 0.009372266711782207
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.1683248744867121, Reinit.: 0.7461519880107127
# 	Loss achieved:  inf 0.04510806602941747
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.13258907516907684, Reinit.: 0.011245295092233487
# 	Loss achieved:  inf 0.17569888440867096
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.001998256789823349, Reinit.: 0.5827155596742113
# 	Loss achieved:  inf 0.07415025211250635
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.10354688908598796, Reinit.: 0.3551874063767869
# 	Loss achieved:  inf 0.11458135449563142
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.06311578670286289, Reinit.: 0.05334613157408785
# 	Loss achieved:  inf 0.16821768612378016
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.009479455074714144, Reinit.: 0.819724222265683
# 	Loss achieved:  inf 0.03203449033072331
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.145662650867771, Reinit.: 0.40660314694979305
# 	Loss achieved:  inf 0.1054449243832048
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 7
# 	Original: 0.1776971411984943, Pot. Opt.: 0.07225221681528951, Reinit.: 0.895368996031594
# 	Loss achieved:  inf 0.01859263028591404
# updated params...
# -----> MODEL  3
# Attempt 0 at minimization...
# <ipython-input-178-00ff8aa49707>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   dy2dt = params['tr_y2'] * 1e-9 * (1 + params['d'] * dy2dthelper) / (1 + dy2dthelper * (1 + (x2 / params['ir_y2'] / 1e-9)**params['f'])) * (1 / (1 + (x5 / params['ir_y21'] / 1e-9)**params['f1'])) - params['dr_y2'] * y2
# -----> MODEL  4
# Attempt 0 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.15711953667925105, Reinit.: 0.7430115678067697
# 	Loss achieved:  5.796279025224719e-07 0.03964842980646299
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.11463256046259016, Reinit.: 0.5731938373369105
# 	Loss achieved:  inf 0.06584807742859602
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.08843291284045712, Reinit.: 0.042053503351646704
# 	Loss achieved:  inf 0.14779293412767816
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.006488056141374999, Reinit.: 0.39530940330342645
# 	Loss achieved:  inf 0.09329226406473201
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.06098872620432114, Reinit.: 0.7651554893425178
# 	Loss achieved:  inf 0.03623204366348756
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.11804894660556559, Reinit.: 0.5372683087687852
# 	Loss achieved:  inf 0.07139070355202556
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.08289028671702758, Reinit.: 0.5465998642200496
# 	Loss achieved:  inf 0.06995102193625391
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.08432996833279924, Reinit.: 0.9657651104328082
# 	Loss achieved:  inf 0.0052817926641780255
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.14899919760487512, Reinit.: 0.6690645618404821
# 	Loss achieved:  inf 0.05105704711437342
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.10322394315467973, Reinit.: 0.23631365225438572
# 	Loss achieved:  inf 0.11782228598514985
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.03645870428390329, Reinit.: 0.5705686842664031
# 	Loss achieved:  inf 0.06625308864392176
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.08802790162513138, Reinit.: 0.69448175191973
# 	Loss achieved:  inf 0.047135657859090296
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.10714533240996285, Reinit.: 0.1570396219373017
# 	Loss achieved:  inf 0.13005276188508852
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.02422822838396463, Reinit.: 0.6272596133315391
# 	Loss achieved:  inf 0.057506755968479914
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.09677423430057323, Reinit.: 0.2799252569055898
# 	Loss achieved:  inf 0.11109384443233965
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.0431871458367135, Reinit.: 0.8031584863439726
# 	Loss achieved:  inf 0.030368903652911255
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.12391208661614189, Reinit.: 0.05851774065534654
# 	Loss achieved:  inf 0.14525281529243866
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.009028174976614496, Reinit.: 0.3010945523854067
# 	Loss achieved:  inf 0.1078278245624153
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.04645316570663785, Reinit.: 0.40185572997829555
# 	Loss achieved:  inf 0.09228229030270849
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.06199869996634467, Reinit.: 0.2880057939256292
# 	Loss achieved:  inf 0.10984717117898223
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.04443381909007092, Reinit.: 0.42033878989943785
# 	Loss achieved:  inf 0.08943070551487241
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.06485028475418074, Reinit.: 0.15558988982234467
# 	Loss achieved:  inf 0.13027642799140893
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.02400456227764421, Reinit.: 0.7821325813683979
# 	Loss achieved:  inf 0.03361280109384593
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.12066818917520722, Reinit.: 0.6552295750835165
# 	Loss achieved:  inf 0.0531915225715973
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 9
# 	Original: 0.15428099026905315, Pot. Opt.: 0.10108946769745585, Reinit.: 0.9589189249649555
# 	Loss achieved:  inf 0.00633802893772395
# updated params...
# -----> MODEL  5
# Attempt 0 at minimization...
# 	what happened here? 54
# 	Original: 0.05102305745586137, Pot. Opt.: 0.0, Reinit.: 0.7217010392481363
# 	Loss achieved:  3.692407641723317e-07 0.01942178415616329
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 54
# 	Original: 0.01894422820005309, Pot. Opt.: 0.0, Reinit.: 0.2966103335431354
# 	Loss achieved:  3.4126564475525085e-07 0.013325174354918071
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.10124696886156943, Reinit.: 0.9050066943142847
# 	Loss achieved:  3.3105495367780107e-07 0.014537413631526124
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 23
# 	Original: 0.028761654633233012, Pot. Opt.: 0.014224241001706888, Reinit.: 0.8760498597746007
# 	Loss achieved:  inf 0.011104644628496446
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.10579458893682538, Reinit.: 0.07517685423838216
# 	Loss achieved:  inf 0.10811111692300303
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.00878811664231879, Reinit.: 0.760371327396452
# 	Loss achieved:  inf 0.02801240816763019
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.08888682539769163, Reinit.: 0.5231271921093554
# 	Loss achieved:  inf 0.0557460657505593
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.06115316781476252, Reinit.: 0.23050864423235995
# 	Loss achieved:  inf 0.0899529497243775
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.02694628384094432, Reinit.: 0.8611355646365219
# 	Loss achieved:  inf 0.016233146063471773
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.10066608750185005, Reinit.: 0.050769125684980154
# 	Loss achieved:  inf 0.11096436168396615
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.005934871881355675, Reinit.: 0.8536025647315382
# 	Loss achieved:  inf 0.017113747978812002
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.09978548558650982, Reinit.: 0.3790443060698713
# 	Loss achieved:  inf 0.07258924469845461
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.04430998886686721, Reinit.: 0.07534877467990875
# 	Loss achieved:  inf 0.10809101955515436
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.008808214010167459, Reinit.: 0.6000737862545518
# 	Loss achieved:  inf 0.046751067869523974
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.07014816569579785, Reinit.: 0.6461182359728933
# 	Loss achieved:  inf 0.04136850698751285
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.07553072657780897, Reinit.: 0.9315819225297877
# 	Loss achieved:  inf 0.007998020818280632
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.10890121274704119, Reinit.: 0.34839651428778773
# 	Loss achieved:  inf 0.07617194806824974
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.04072728549707208, Reinit.: 0.6312919362204529
# 	Loss achieved:  inf 0.04310169006518286
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.07379754350013897, Reinit.: 0.8920473556395903
# 	Loss achieved:  inf 0.012619581387081663
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.10427965217824016, Reinit.: 0.6634688203197948
# 	Loss achieved:  inf 0.0393402369754496
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.07755899658987223, Reinit.: 0.07837358950873285
# 	Loss achieved:  inf 0.1077374210199878
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.009161812545334018, Reinit.: 0.5643045240085081
# 	Loss achieved:  inf 0.050932467211283486
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.06596676635403834, Reinit.: 0.6022665537538374
# 	Loss achieved:  inf 0.04649473502947053
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.07040449853585129, Reinit.: 0.45340599368276246
# 	Loss achieved:  inf 0.06389642040988375
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 25
# 	Original: 0.11689923356532182, Pot. Opt.: 0.05300281315543808, Reinit.: 0.11654431709357238
# 	Loss achieved:  inf 0.10327529222068937
# updated params...
# -----> MODEL  6
# Attempt 0 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 2.000599425472906, Reinit.: 0.03181587699381416
# 	Loss achieved:  3.9152741795413403e-07 1.468547585224212
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.04825851635118977, Reinit.: 0.11668050038214561
# 	Loss achieved:  inf 1.3398244066608922
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.17698169491450946, Reinit.: 0.33406708569774557
# 	Loss achieved:  inf 1.0100911076535486
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.5067149939218532, Reinit.: 0.869990301609366
# 	Loss achieved:  inf 0.1971995037828913
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 1.3196065977925104, Reinit.: 0.07391526724035125
# 	Loss achieved:  inf 1.4046909732256605
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.11211512834974117, Reinit.: 0.029389334618178276
# 	Loss achieved:  inf 1.4722281795053078
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.044577922070093985, Reinit.: 0.9064288681508554
# 	Loss achieved:  inf 0.1438892479611122
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.24792430142211863, Reinit.: 0.09012702013030516
# 	Loss achieved:  inf 0.35650056173064204
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.03531298765258876, Reinit.: 0.5557979302466459
# 	Loss achieved:  inf 0.17404438959343915
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.21776915978979167, Reinit.: 0.029327537639539436
# 	Loss achieved:  inf 0.3803226227660126
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.011490926617218246, Reinit.: 0.2608333497977632
# 	Loss achieved:  inf 0.2896155088014514
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.1021980405817794, Reinit.: 0.2699211236395962
# 	Loss achieved:  inf 0.28605479587649074
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 35
# 	Original: 0.3918135493832308, Pot. Opt.: 0.10575875350674008, Reinit.: 0.7540227005839785
# 	Loss achieved:  inf 0.14192926372009884
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 1.374876837855303, Reinit.: 0.19784251978665568
# 	Loss achieved:  inf 1.2167173604119503
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.30008874116345147, Reinit.: 0.6590584158016668
# 	Loss achieved:  inf 0.5171422751928154
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.9996638263825863, Reinit.: 0.8549219181268619
# 	Loss achieved:  inf 0.22005531979003146
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 1.2967507817853703, Reinit.: 0.5162859617319597
# 	Loss achieved:  inf 0.7337004046626409
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.7831056969127609, Reinit.: 0.3700564363262664
# 	Loss achieved:  inf 0.9555022410284717
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.56130386054693, Reinit.: 0.1229186727836239
# 	Loss achieved:  inf 1.3303623086996508
# updated params...
# Attempt 19 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.186443792875751, Reinit.: 0.33395463632905886
# 	Loss achieved:  inf 1.010261671542091
# updated params...
# Attempt 20 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.5065444300333108, Reinit.: 0.3754880055332095
# 	Loss achieved:  inf 0.9472636037142513
# updated params...
# Attempt 21 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.5695424978611504, Reinit.: 0.3028766342723038
# 	Loss achieved:  inf 1.0574009746865498
# updated params...
# Attempt 22 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.4594051268888519, Reinit.: 0.11519254885478025
# 	Loss achieved:  inf 1.3420813406164485
# updated params...
# Attempt 23 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 0.17472476095895326, Reinit.: 0.800189891481399
# 	Loss achieved:  inf 0.30307319175745717
# updated params...
# Attempt 24 at minimization...
# 	what happened here? 13
# 	Original: 1.5168061015754017, Pot. Opt.: 1.2137329098179446, Reinit.: 0.14466840733818764
# 	Loss achieved:  inf 1.297372178619643
# updated params...
# -----> MODEL  7
# Attempt 0 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.35828239662962497, Reinit.: 0.2964901852416617
# 	Loss achieved:  3.3864598632394264e-07 0.3200722108236578
# updated params...
# Attempt 1 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.13489260147765367, Reinit.: 0.43975413822428744
# 	Loss achieved:  inf 0.2548921533453735
# updated params...
# Attempt 2 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.2000726589559379, Reinit.: 0.7185717437790494
# 	Loss achieved:  inf 0.12803995376785016
# updated params...
# Attempt 3 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.32692485853346126, Reinit.: 0.17753189495872157
# 	Loss achieved:  inf 0.3741940470339205
# updated params...
# Attempt 4 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.0807707652673909, Reinit.: 0.12581057553546493
# 	Loss achieved:  inf 0.39772542741729866
# updated params...
# Attempt 5 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.05723938488401276, Reinit.: 0.8572554522068351
# 	Loss achieved:  inf 0.06494374639375283
# updated params...
# Attempt 6 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.3900210659075586, Reinit.: 0.6235562514868679
# 	Loss achieved:  inf 0.1712686593842792
# updated params...
# Attempt 7 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.2836961529170322, Reinit.: 0.5830656302339859
# 	Loss achieved:  inf 0.18969046728256017
# updated params...
# Attempt 8 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.26527434501875125, Reinit.: 0.26197178897442686
# 	Loss achieved:  inf 0.3357768665023225
# updated params...
# Attempt 9 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.11918794579898888, Reinit.: 0.46913024975603324
# 	Loss achieved:  inf 0.24152705627619042
# updated params...
# Attempt 10 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.213437756025121, Reinit.: 0.27778262186223335
# 	Loss achieved:  inf 0.32858349388519426
# updated params...
# Attempt 11 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.12638131841611716, Reinit.: 0.8554541592989789
# 	Loss achieved:  inf 0.06576327128347531
# updated params...
# Attempt 12 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.3892015410178361, Reinit.: 0.875925204109562
# 	Loss achieved:  inf 0.056449666223616635
# updated params...
# Attempt 13 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.3985151460776948, Reinit.: 0.28635882841068594
# 	Loss achieved:  inf 0.32468162168262027
# updated params...
# Attempt 14 at minimization...
# 	what happened here? 6
# 	Original: 0.4549648123013114, Pot. Opt.: 0.13028319061869117, Reinit.: 0.9620794849985701
# 	Loss achieved:  inf 0.04097024306155489
# updated params...
# Attempt 15 at minimization...
# 	what happened here? 51
# 	Original: 0.18544990185869495, Pot. Opt.: 0.14447965879714006, Reinit.: 0.5157607068221796
# 	Loss achieved:  inf 0.08980212939595061
# updated params...
# Attempt 16 at minimization...
# 	what happened here? 51
# 	Original: 0.18544990185869495, Pot. Opt.: 0.09564777246274433, Reinit.: 0.9654132143032431
# 	Loss achieved:  inf 0.031056018001543683
# updated params...
# Attempt 17 at minimization...
# 	what happened here? 25
# 	Original: 0.031056018001543687, Pot. Opt.: 3.469446951953614e-18, Reinit.: 0.29100249119082455
# 	Loss achieved:  inf 0.0232098960686397
# updated params...
# Attempt 18 at minimization...
# 	what happened here? 41
# 	Original: 0.917952330395884, Pot. Opt.: 0.9179523154947228, Reinit.: 5.7196776801168605
# 	Loss achieved:  1.9344989013909859e-07 4.332439125180712
# updated params...
# Attempt 19 at minimization...

# %%
# checking the predicted parameters
np.abs(opt_params.x - parameters).sort_values(ascending=False)
# Out:
# pr_z6    2037.006040
# pr_z7     599.285356
# pr_z1     373.229736
# pr_z5     350.545564
# ar_y2     240.587328
#             ...
# dr_y3       0.051832
# tr_y1       0.047930
# dr_z7       0.017366
# tr_y6       0.014067
# tr_y5       0.002673
# Length: 64, dtype: float64

# %%
# just some analysis
np.abs(opt_params.x - parameters)[np.abs(opt_params.x - parameters) > 1e-2]
# Out:
# dr_x1    0.089206
# dr_x2    0.656375
# dr_x5    1.165749
# dr_x6    0.874015
# dr_y1    0.107812
#            ...
# e        4.255178
# f        7.246722
# f1       0.598795
# vc       0.734832
# vn       0.734832
# Length: 63, dtype: float64

# %%
# taking ensemble average
final_params = np.zeros(opt_params.x.shape)
valid_opt = 0
for opt in list_opt:
    if opt is not None:
        final_params += opt.x
        valid_opt += 1
final_params = final_params/valid_opt
np.abs(final_params - parameters).sort_values(ascending = False)
# Out:
# pr_z6      2099.429478
# pr_z5       412.688581
# ar_y2       240.467512
# pr_z1       225.917736
# pr_z2       210.316730
#               ...
# dr_z5         0.069270
# kd_z4         0.055931
# dr_x1         0.025701
# dr_y1         0.005886
# impr_z6       0.004829
# Length: 64, dtype: float64

# %%
# observing the the solution for the odes with the optimized parameters
# however, the parameters need to be fully optimized and the following results are not great
clock2 = CircadianModel(init, t_start, t_end, dt, pd.Series(final_params, params_list))

# %%
soln2 = clock2.solver()

# %%
plt_start = int(t_start / dt)
plt_end = int(t_end / dt)
fig, axes = plt.subplots(6, 3, figsize = (20,20), constrained_layout = True)
for i, ax in zip(range(len(init)), axes.flat):
    time = soln2.t[plt_start:plt_end]
    prot = soln2.y[i, plt_start:plt_end]
    ax.plot(time, prot, label = list(init.keys())[i], lw = 2)
    ax.tick_params(axis='both', which = 'major', labelsize = '15', width = 1.5)
    ax.yaxis.offsetText.set_fontsize(15)
    var = list(init.keys())[i]
    ax.set_title('{} ({})'.format(protein_mapping[var], var), fontsize = 18, weight = 'bold')
# _ = fig.supylabel('Concentration (nmol/L)', fontsize = 22, weight = 'bold')
# _ = fig.supxlabel('Time (hours)', fontsize = 22, weight = 'bold')
# plt.savefig('circadian_clock_portion.png', bbox_inches = 'tight', pad_inches = 0.4, dpi = 300)
